# %%
import json
import tweepy

# %%
consumer_key = "zfbeOpNGitzmlOdDp9QtdEDC5"
consumer_secret = "y1G98Alzr854ziwjcmQCYHv1QSDhICUucPXSNpyq9AClwsO5Be"
access_token = "971209045104214016-2IfMVViLMR35wP18Hq4LqcFLOc7cCTj"
access_token_secret = "9YA3TlU6B73fPrtK0s55hwPHzifTnKjt83gwxK9JxqGob"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
target_user = "BBC"
target_user = "FOX"
target_user = "CNN"
target_user = "CBS"
target_user = "NYT"

# %%
for x in range(5):
    public_tweets = api.user_timeline(target_user)
for tweet in public_tweets:

    # Utilize JSON dumps to generate a pretty-printed json
    print(json.dumps(tweet, sort_keys=True, indent=4))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Mar 17 22:34:55 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "nytimes.com/2018/03/17/spo\u2026",
#                 "expanded_url": "https://www.nytimes.com/2018/03/17/sports/ncaabasketball/ncaa-womens-tournament-uconn-rout.html?partner=rss&emc=rss",
#                 "indices": [
#                     67,
#                     90
#                 ],
#                 "url": "https://t.co/EsHAkD5UnI"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 975138438402969601,
#     "id_str": "975138438402969601",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
# ...
